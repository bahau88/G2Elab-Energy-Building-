# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import datetime
# %matplotlib inline

# %% [markdown]
# **IMPORT RAW DATA**

# %%
# Read the Data
df = pd.read_csv("https://raw.githubusercontent.com/bahau88/G2Elab-Energy-Building-/main/dataset/tmp-168346748651474.csv")


# convert the 'DTSTART' and 'DTEND' columns to datetime format
df['DTSTART'] = pd.to_datetime(df['DTSTART'])
df['DTEND'] = pd.to_datetime(df['DTEND'])

# extract the date and time components from the 'DTSTART' column
df['DATE'] = df['DTSTART'].dt.date
df['START-TIME'] = df['DTSTART'].dt.strftime('%H:%M')

# extract the date and time components from the 'DTSTART' column
df['DATE2'] = df['DTEND'].dt.date
df['END-TIME'] = df['DTEND'].dt.strftime('%H:%M')

df.head(10)
# Out:
#                                  SUMMARY             DTSTART  \
# 0                        Soutenances PFE 2022-09-01 07:00:00
# 1         Tutorat de mathématiques - AST 2022-09-01 08:00:00
# 2         Tutorat de mathématiques - AST 2022-09-01 08:00:00
# 3                                Rentrée 2022-09-01 08:30:00
# 4                  Repas soutenances PFE 2022-09-01 09:00:00
# 5       Entretiens recrutement Gest Scol 2022-09-01 09:00:00
# 6         Tutorat de mathématiques - AST 2022-09-01 10:15:00
# 7         Tutorat de mathématiques - AST 2022-09-01 10:15:00
# 8                                   DRiu 2022-09-01 10:30:00
# 9  INSCRIPTIONS ETUDIANTS INTERNATIONAUX 2022-09-01 13:00:00
#
#                 DTEND  DUE                                              NOTES  \
# 0 2022-09-01 18:00:00  NaN                      (Exporté le:28/02/2023 14:40)
# 1 2022-09-01 10:00:00  NaN  3EM1SMA7_2022_S5_TD_G2GUERIN DUGUE Anne(Export...
# 2 2022-09-01 10:00:00  NaN  3EM1SMA7_2022_S5_TD_G1VEZIER Antoine(Exporté l...
# 3 2022-09-01 12:00:00  NaN                1A-ALT(Exporté le:28/02/2023 14:40)
# 4 2022-09-01 14:30:00  NaN                      (Exporté le:28/02/2023 14:40)
# 5 2022-09-01 13:00:00  NaN  Réservations ReSEdALefebvre Genevieve(Exporté ...
# 6 2022-09-01 12:15:00  NaN  3EM1SMA7_2022_S5_TD_G2GUERIN DUGUE Anne(Export...
# 7 2022-09-01 12:15:00  NaN  3EM1SMA7_2022_S5_TD_G1VEZIER Antoine(Exporté l...
# 8 2022-09-01 12:30:00  NaN  Réservations ReSEdABakouche Fadwa(Exporté le:2...
# 9 2022-09-01 16:00:00  NaN                      (Exporté le:28/02/2023 14:40)
#
#    ATTENDEE                                           LOCATION  PRIORITY  URL  \
# 0       NaN  G-2A004,G-2A005,G-2B002,G-2B012,G-2B013,G-2C00...       NaN  NaN
# 1       NaN                                    G-4D008 TD-info       NaN  NaN
# 2       NaN                                            G-4D003       NaN  NaN
# 3       NaN                               G-0B007-Amphi Bergès       NaN  NaN
# 4       NaN                           G-0D006-Salle des forums       NaN  NaN
# 5       NaN                                            G-1C004       NaN  NaN
# 6       NaN                                    G-4D008 TD-info       NaN  NaN
# 7       NaN                                            G-4D003       NaN  NaN
# 8       NaN                                            G-1C003       NaN  NaN
# 9       NaN                       G-1B016-Projet-Vie étudiante       NaN  NaN
#
#    CALENDAR  UID  ORGANIZER  CATEGORIES  DURATION  \
# 0       NaN  NaN        NaN         NaN       NaN
# 1       NaN  NaN        NaN         NaN       NaN
# 2       NaN  NaN        NaN         NaN       NaN
# 3       NaN  NaN        NaN         NaN       NaN
# 4       NaN  NaN        NaN         NaN       NaN
# 5       NaN  NaN        NaN         NaN       NaN
# 6       NaN  NaN        NaN         NaN       NaN
# 7       NaN  NaN        NaN         NaN       NaN
# 8       NaN  NaN        NaN         NaN       NaN
# 9       NaN  NaN        NaN         NaN       NaN
#
#    REPLACES RECURRENT EVENT FROM        DATE START-TIME       DATE2 END-TIME
# 0                            NaN  2022-09-01      07:00  2022-09-01    18:00
# 1                            NaN  2022-09-01      08:00  2022-09-01    10:00
# 2                            NaN  2022-09-01      08:00  2022-09-01    10:00
# 3                            NaN  2022-09-01      08:30  2022-09-01    12:00
# 4                            NaN  2022-09-01      09:00  2022-09-01    14:30
# 5                            NaN  2022-09-01      09:00  2022-09-01    13:00
# 6                            NaN  2022-09-01      10:15  2022-09-01    12:15
# 7                            NaN  2022-09-01      10:15  2022-09-01    12:15
# 8                            NaN  2022-09-01      10:30  2022-09-01    12:30
# 9                            NaN  2022-09-01      13:00  2022-09-01    16:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11814 entries, 0 to 11813
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   SUMMARY                        11814 non-null  object
#  1   DTSTART                        11814 non-null  datetime64[ns]
#  2   DTEND                          11814 non-null  datetime64[ns]
#  3   DUE                            0 non-null      float64
#  4   NOTES                          11814 non-null  object
#  5   ATTENDEE                       0 non-null      float64
#  6   LOCATION                       11814 non-null  object
#  7   PRIORITY                       0 non-null      float64
#  8   URL                            0 non-null      float64
#  9   CALENDAR                       0 non-null      float64
#  10  UID                            0 non-null      float64
#  11  ORGANIZER                      0 non-null      float64
#  12  CATEGORIES                     0 non-null      float64
#  13  DURATION                       0 non-null      float64
#  14  REPLACES RECURRENT EVENT FROM  0 non-null      float64
#  15  DATE                           11814 non-null  object
#  16  START-TIME                     11814 non-null  object
#  17  DATE2                          11814 non-null  object
#  18  END-TIME                       11814 non-null  object
# dtypes: datetime64[ns](2), float64(10), object(7)
# memory usage: 1.7+ MB

# %%
# data cleaning, remove the unnecessary columns
#df = df.drop(['SUMMARY', 'DTSTART-DATE','DTEND-DATE', 'PRIORITY', 'URL', 'CALENDAR', 'UID', 'ORGANIZER', 'CATEGORIES', 'DURATION', 'REPLACES RECURRENT EVENT FROM', 'NOTES', 'DUE', 'ATTENDEE'], axis=1)
df = df.drop(['SUMMARY',	'DUE',	'NOTES',	'ATTENDEE'	,'PRIORITY',	'URL'	,'CALENDAR'	,'UID',	'ORGANIZER',	'CATEGORIES',	'DURATION',	'REPLACES RECURRENT EVENT FROM', 'DTSTART', 'DTEND', 'DATE2'], axis=1)

df.head(5)
# Out:
#                                             LOCATION        DATE START-TIME  \
# 0  G-2A004,G-2A005,G-2B002,G-2B012,G-2B013,G-2C00...  2022-09-01      07:00
# 1                                    G-4D008 TD-info  2022-09-01      08:00
# 2                                            G-4D003  2022-09-01      08:00
# 3                               G-0B007-Amphi Bergès  2022-09-01      08:30
# 4                           G-0D006-Salle des forums  2022-09-01      09:00
#
#   END-TIME
# 0    18:00
# 1    10:00
# 2    10:00
# 3    12:00
# 4    14:30

# %%
# Rearrange the columns
df = df[['DATE', 'START-TIME', 'END-TIME', 'LOCATION']]
df.head(5)
# Out:
#          DATE START-TIME END-TIME  \
# 0  2022-09-01      07:00    18:00
# 1  2022-09-01      08:00    10:00
# 2  2022-09-01      08:00    10:00
# 3  2022-09-01      08:30    12:00
# 4  2022-09-01      09:00    14:30
#
#                                             LOCATION
# 0  G-2A004,G-2A005,G-2B002,G-2B012,G-2B013,G-2C00...
# 1                                    G-4D008 TD-info
# 2                                            G-4D003
# 3                               G-0B007-Amphi Bergès
# 4                           G-0D006-Salle des forums

# %%
# convert the start_time and end_time columns to datetime objects
start_times = pd.to_datetime(df['START-TIME'], format='%H:%M')
end_times = pd.to_datetime(df['END-TIME'], format='%H:%M')

# calculate the duration between start_time and end_time
durations = (end_times - start_times).dt.total_seconds() / 3600

# add the duration column to the dataframe
df['DURATION'] = durations

#re order the position of column
df = df.reindex(columns=['DATE', 'START-TIME', 'END-TIME', 'DURATION', 'LOCATION'])
df.head(20)

# print the modified dataframe
df.head(5)
# Out:
#          DATE START-TIME END-TIME  DURATION  \
# 0  2022-09-01      07:00    18:00      11.0
# 1  2022-09-01      08:00    10:00       2.0
# 2  2022-09-01      08:00    10:00       2.0
# 3  2022-09-01      08:30    12:00       3.5
# 4  2022-09-01      09:00    14:30       5.5
#
#                                             LOCATION
# 0  G-2A004,G-2A005,G-2B002,G-2B012,G-2B013,G-2C00...
# 1                                    G-4D008 TD-info
# 2                                            G-4D003
# 3                               G-0B007-Amphi Bergès
# 4                           G-0D006-Salle des forums

# %%
# define a function to count the number of components containing 'G-', the componnets which contain other characters in not counted for example (,*)
def count_g_components(row):
    components = row.split(',')
    return sum(['G-' in component for component in components])

# add a new column to the dataframe with the G- component count
df['NUMBER OF ROOMS'] = df['LOCATION'].apply(count_g_components)

# print the modified dataframe
df.head(30)
# Out:
#           DATE START-TIME END-TIME  DURATION  \
# 0   2022-09-01      07:00    18:00     11.00
# 1   2022-09-01      08:00    10:00      2.00
# 2   2022-09-01      08:00    10:00      2.00
# 3   2022-09-01      08:30    12:00      3.50
# 4   2022-09-01      09:00    14:30      5.50
# 5   2022-09-01      09:00    13:00      4.00
# 6   2022-09-01      10:15    12:15      2.00
# 7   2022-09-01      10:15    12:15      2.00
# 8   2022-09-01      10:30    12:30      2.00
# 9   2022-09-01      13:00    16:00      3.00
# 10  2022-09-01      13:30    18:00      4.50
# 11  2022-09-01      13:30    15:30      2.00
# 12  2022-09-01      13:30    14:30      1.00
# 13  2022-09-01      14:00    16:00      2.00
# 14  2022-09-01      14:00    15:00      1.00
# 15  2022-09-01      14:30    15:30      1.00
# 16  2022-09-01      15:45    17:45      2.00
# 17  2022-09-01      16:45    18:00      1.25
# 18  2022-09-02      07:00    18:00     11.00
# 19  2022-09-02      08:00    09:00      1.00
# 20  2022-09-02      08:00    09:00      1.00
# 21  2022-09-02      08:00    10:00      2.00
# 22  2022-09-02      09:00    10:00      1.00
# 23  2022-09-02      09:00    14:30      5.50
# 24  2022-09-02      09:00    10:00      1.00
# 25  2022-09-02      09:00    10:00      1.00
# 26  2022-09-02      10:15    12:15      2.00
# 27  2022-09-02      13:00    16:00      3.00
# 28  2022-09-02      13:00    16:00      3.00
# 29  2022-09-02      13:30    15:30      2.00
#
#                                              LOCATION  NUMBER OF ROOMS
# 0   G-2A004,G-2A005,G-2B002,G-2B012,G-2B013,G-2C00...               16
# 1                                     G-4D008 TD-info                1
# 2                                             G-4D003                1
# 3                                G-0B007-Amphi Bergès                1
# 4                            G-0D006-Salle des forums                1
# 5                                             G-1C004                1
# 6                                     G-4D008 TD-info                1
# 7                                             G-4D003                1
# 8                                             G-1C003                1
# 9                        G-1B016-Projet-Vie étudiante                1
# 10                           G-1D003-Salle du Conseil                1
# 11                                       G-2A007-info                1
# 12                                            G-2B009                1
# 13                                            G-1C003                1
# 14                                            G-1C004                1
# 15                                            G-2B009                1
# 16                                            G-4D003                1
# 17                                            G-1C004                1
# 18  G-2A004,G-2A005,G-2B002,G-2B012,G-2B013,G-2C00...               16
# 19                                            G-2B010                1
# 20                                            G-2B009                1
# 21                                            G-4D003                1
# 22                                            G-2B010                1
# 23                           G-0D006-Salle des forums                1
# 24                              G-1C002-Amphi Coulomb                1
# 25                                            G-2B009                1
# 26                                    G-4D008 TD-info                1
# 27                       G-1B016-Projet-Vie étudiante                1
# 28                                            G-1C003                1
# 29                                            G-4D003                1

# %%
# Create column that shows the total duration (duration x number of rooms)
df['TOTAL DURATION'] = df['DURATION'] * df['NUMBER OF ROOMS']

# multiply the component count by 15 (max people) to create a new column
df['MAX PEOPLE'] = df['NUMBER OF ROOMS'].apply(lambda x: x * 15)

#df = df.drop(['date'], axis=1)
df.head(50)
# Out:
#           DATE START-TIME END-TIME  DURATION  \
# 0   2022-09-01      07:00    18:00     11.00
# 1   2022-09-01      08:00    10:00      2.00
# 2   2022-09-01      08:00    10:00      2.00
# 3   2022-09-01      08:30    12:00      3.50
# 4   2022-09-01      09:00    14:30      5.50
# 5   2022-09-01      09:00    13:00      4.00
# 6   2022-09-01      10:15    12:15      2.00
# 7   2022-09-01      10:15    12:15      2.00
# 8   2022-09-01      10:30    12:30      2.00
# 9   2022-09-01      13:00    16:00      3.00
# 10  2022-09-01      13:30    18:00      4.50
# 11  2022-09-01      13:30    15:30      2.00
# 12  2022-09-01      13:30    14:30      1.00
# 13  2022-09-01      14:00    16:00      2.00
# 14  2022-09-01      14:00    15:00      1.00
# 15  2022-09-01      14:30    15:30      1.00
# 16  2022-09-01      15:45    17:45      2.00
# 17  2022-09-01      16:45    18:00      1.25
# 18  2022-09-02      07:00    18:00     11.00
# 19  2022-09-02      08:00    09:00      1.00
# 20  2022-09-02      08:00    09:00      1.00
# 21  2022-09-02      08:00    10:00      2.00
# 22  2022-09-02      09:00    10:00      1.00
# 23  2022-09-02      09:00    14:30      5.50
# 24  2022-09-02      09:00    10:00      1.00
# 25  2022-09-02      09:00    10:00      1.00
# 26  2022-09-02      10:15    12:15      2.00
# 27  2022-09-02      13:00    16:00      3.00
# 28  2022-09-02      13:00    16:00      3.00
# 29  2022-09-02      13:30    15:30      2.00
# 30  2022-09-02      13:30    15:30      2.00
# 31  2022-09-02      13:30    15:30      2.00
# 32  2022-09-02      15:45    17:45      2.00
# 33  2022-09-05      07:00    18:00     11.00
# 34  2022-09-05      07:30    13:00      5.50
# 35  2022-09-05      07:30    11:00      3.50
# 36  2022-09-05      08:00    18:30     10.50
# 37  2022-09-05      09:00    14:30      5.50
# 38  2022-09-05      10:00    12:00      2.00
# 39  2022-09-05      10:00    12:00      2.00
# 40  2022-09-05      11:00    16:00      5.00
# 41  2022-09-05      13:30    14:30      1.00
# 42  2022-09-05      14:00    14:45      0.75
# 43  2022-09-05      14:00    14:45      0.75
# 44  2022-09-05      14:00    14:45      0.75
# 45  2022-09-05      15:00    16:00      1.00
# 46  2022-09-05      15:00    16:00      1.00
# 47  2022-09-05      15:00    16:00      1.00
# 48  2022-09-05      15:00    16:00      1.00
# 49  2022-09-05      15:00    16:00      1.00
#
#                                              LOCATION  NUMBER OF ROOMS  \
# 0   G-2A004,G-2A005,G-2B002,G-2B012,G-2B013,G-2C00...               16
# 1                                     G-4D008 TD-info                1
# 2                                             G-4D003                1
# 3                                G-0B007-Amphi Bergès                1
# 4                            G-0D006-Salle des forums                1
# 5                                             G-1C004                1
# 6                                     G-4D008 TD-info                1
# 7                                             G-4D003                1
# 8                                             G-1C003                1
# 9                        G-1B016-Projet-Vie étudiante                1
# 10                           G-1D003-Salle du Conseil                1
# 11                                       G-2A007-info                1
# 12                                            G-2B009                1
# 13                                            G-1C003                1
# 14                                            G-1C004                1
# 15                                            G-2B009                1
# 16                                            G-4D003                1
# 17                                            G-1C004                1
# 18  G-2A004,G-2A005,G-2B002,G-2B012,G-2B013,G-2C00...               16
# 19                                            G-2B010                1
# 20                                            G-2B009                1
# 21                                            G-4D003                1
# 22                                            G-2B010                1
# 23                           G-0D006-Salle des forums                1
# 24                              G-1C002-Amphi Coulomb                1
# 25                                            G-2B009                1
# 26                                    G-4D008 TD-info                1
# 27                       G-1B016-Projet-Vie étudiante                1
# 28                                            G-1C003                1
# 29                                            G-4D003                1
# 30                                       G-2A007-info                1
# 31                                            G-1C004                1
# 32                                       G-2A007-info                1
# 33  G-2A004,G-2A005,G-2B002,G-2B012,G-2B013,G-2C00...               16
# 34  G-1A002-Amphi Ampère,G-1C002-Amphi Coulomb,G-0...                3
# 35                                      G-0B018-Agora                1
# 36  G-3A012-Enveloppe épaisse,G-3A012-Flambement,G...                8
# 37                           G-0D006-Salle des forums                1
# 38                                            G-1C004                1
# 39                                            G-2A006                1
# 40                         G-1B012-info-vie étudiante                1
# 41                                            G-1C004                1
# 42                               G-0B007-Amphi Bergès                1
# 43                               G-1A002-Amphi Ampère                1
# 44                              G-1C002-Amphi Coulomb                1
# 45                                            G-2A006                1
# 46                                            G-2B009                1
# 47                                            G-4D003                1
# 48                              G-1C002-Amphi Coulomb                1
# 49                               G-1A002-Amphi Ampère                1
#
#     TOTAL DURATION  MAX PEOPLE
# 0           176.00         240
# 1             2.00          15
# 2             2.00          15
# 3             3.50          15
# 4             5.50          15
# 5             4.00          15
# 6             2.00          15
# 7             2.00          15
# 8             2.00          15
# 9             3.00          15
# 10            4.50          15
# 11            2.00          15
# 12            1.00          15
# 13            2.00          15
# 14            1.00          15
# 15            1.00          15
# 16            2.00          15
# 17            1.25          15
# 18          176.00         240
# 19            1.00          15
# 20            1.00          15
# 21            2.00          15
# 22            1.00          15
# 23            5.50          15
# 24            1.00          15
# 25            1.00          15
# 26            2.00          15
# 27            3.00          15
# 28            3.00          15
# 29            2.00          15
# 30            2.00          15
# 31            2.00          15
# 32            2.00          15
# 33          176.00         240
# 34           16.50          45
# 35            3.50          15
# 36           84.00         120
# 37            5.50          15
# 38            2.00          15
# 39            2.00          15
# 40            5.00          15
# 41            1.00          15
# 42            0.75          15
# 43            0.75          15
# 44            0.75          15
# 45            1.00          15
# 46            1.00          15
# 47            1.00          15
# 48            1.00          15
# 49            1.00          15

# %% [markdown]
# **Plotting**

# %%
import matplotlib.pyplot as plt
# Convert date column to datetime object
df['DATE'] = pd.to_datetime(df['DATE'], format='%Y-%m-%d')

# Group the data by date and sum the total duration
agg_df = df.groupby('DATE')['TOTAL DURATION'].sum().reset_index()

# Create a bar plot
plt.figure(figsize=(25, 8))
plt.bar(agg_df['DATE'], agg_df['TOTAL DURATION'])
plt.xlabel('Date')
plt.ylabel('Total Duration')
plt.title('Total Duration per Date')
plt.show()

# %%
# convert the date column to datetime format
df['date'] = pd.to_datetime(df['DATE'], format='%Y-%m-%d')

# filter the dataframe to include only the rows between two dates
start_date = pd.to_datetime('2022-09-01', format='%Y-%m-%d')
end_date = pd.to_datetime('2022-09-30', format='%Y-%m-%d')
filtered_df = df.loc[(df['date'] >= start_date) & (df['date'] <= end_date)]

# group the filtered dataframe by date and sum the total duration for each date
grouped_df = filtered_df.groupby('date', as_index=False)['TOTAL DURATION'].sum()

# create a bar chart of the grouped dataframe
plt.figure(figsize=(25, 6))  # set the figure size to 25x6 inches
plt.bar(grouped_df['date'], grouped_df['TOTAL DURATION'])
plt.xlabel('DATE')
plt.ylabel('DURATION (hour)')
plt.title('Total Class Duration vs. Date in one Month')

plt.show()

# %% [markdown]
# **BREAK DOWN 1 ROW 1 LOCATION**

# %%
# split the rows into multiple rows and keep only the components containing 'G-'
df = df.assign(LOCATION=df['LOCATION'].str.split(',')).explode('LOCATION')
df = df[df['LOCATION'].str.contains('G-')]

df = df.drop(['NUMBER OF ROOMS', 'TOTAL DURATION', 'date', 'MAX PEOPLE', 'DURATION'], axis=1)
# print the modified dataframe
df.head(20)
# Out:
#         DATE START-TIME END-TIME                  LOCATION
# 0 2022-09-01      07:00    18:00                   G-2A004
# 0 2022-09-01      07:00    18:00                   G-2A005
# 0 2022-09-01      07:00    18:00                   G-2B002
# 0 2022-09-01      07:00    18:00                   G-2B012
# 0 2022-09-01      07:00    18:00                   G-2B013
# 0 2022-09-01      07:00    18:00                   G-2C001
# 0 2022-09-01      07:00    18:00                   G-2C002
# 0 2022-09-01      07:00    18:00                   G-2C003
# 0 2022-09-01      07:00    18:00                   G-2C004
# 0 2022-09-01      07:00    18:00                   G-2C007
# 0 2022-09-01      07:00    18:00                   G-2C008
# 0 2022-09-01      07:00    18:00            G-4D001-Projet
# 0 2022-09-01      07:00    18:00            G-4D005-Projet
# 0 2022-09-01      07:00    18:00            G-4D007-Projet
# 0 2022-09-01      07:00    18:00            G-4D009-Projet
# 0 2022-09-01      07:00    18:00            G-4D010-Projet
# 1 2022-09-01      08:00    10:00           G-4D008 TD-info
# 2 2022-09-01      08:00    10:00                   G-4D003
# 3 2022-09-01      08:30    12:00      G-0B007-Amphi Bergès
# 4 2022-09-01      09:00    14:30  G-0D006-Salle des forums

# %% [markdown]
# **ADDITIONAL PART - BREAK DOWN INTO 1 HOUR INTERVAL**

# %%
# Convert start and end times to datetime objects
df['START-TIME'] = pd.to_datetime(df['START-TIME'])
df['END-TIME'] = pd.to_datetime(df['END-TIME'])

# Create a new dataframe to store the split rows
new_rows = []

# Loop through each row in the original dataset
for _, row in df.iterrows():

    # Calculate the duration between start and end times
    duration = row['END-TIME'] - row['START-TIME']

    # If the duration is less than or equal to 1 hour, add the row to the new dataframe as is
    if duration <= pd.Timedelta(hours=1):
        new_rows.append(row)

    # If the duration is more than 1 hour, split the row into multiple rows (one for each hour) and add them to the new dataframe
    else:
        for i in range(int(duration.total_seconds() / 3600)):
            new_start_time = row['START-TIME'] + pd.Timedelta(hours=i)
            new_end_time = new_start_time + pd.Timedelta(hours=1)
            new_row = {
                'DATE': row['DATE'],
                'START-TIME': new_start_time.strftime('%H:%M'),
                'END-TIME': new_end_time.strftime('%H:%M'),
                'LOCATION': row['LOCATION']
            }
            new_rows.append(new_row)

# Create a new dataframe from the list of split rows
new_df = pd.DataFrame(new_rows)

new_df['START-TIME'] = pd.to_datetime(new_df['START-TIME']).dt.strftime('%H:%M')
new_df['END-TIME'] = pd.to_datetime(new_df['END-TIME']).dt.strftime('%H:%M')


# Show the first 50 rows of the new dataframe
new_df.head(50)
# Out:
#          DATE START-TIME END-TIME LOCATION
# 0  2022-09-01      07:00    08:00  G-2A004
# 1  2022-09-01      08:00    09:00  G-2A004
# 2  2022-09-01      09:00    10:00  G-2A004
# 3  2022-09-01      10:00    11:00  G-2A004
# 4  2022-09-01      11:00    12:00  G-2A004
# 5  2022-09-01      12:00    13:00  G-2A004
# 6  2022-09-01      13:00    14:00  G-2A004
# 7  2022-09-01      14:00    15:00  G-2A004
# 8  2022-09-01      15:00    16:00  G-2A004
# 9  2022-09-01      16:00    17:00  G-2A004
# 10 2022-09-01      17:00    18:00  G-2A004
# 11 2022-09-01      07:00    08:00  G-2A005
# 12 2022-09-01      08:00    09:00  G-2A005
# 13 2022-09-01      09:00    10:00  G-2A005
# 14 2022-09-01      10:00    11:00  G-2A005
# 15 2022-09-01      11:00    12:00  G-2A005
# 16 2022-09-01      12:00    13:00  G-2A005
# 17 2022-09-01      13:00    14:00  G-2A005
# 18 2022-09-01      14:00    15:00  G-2A005
# 19 2022-09-01      15:00    16:00  G-2A005
# 20 2022-09-01      16:00    17:00  G-2A005
# 21 2022-09-01      17:00    18:00  G-2A005
# 22 2022-09-01      07:00    08:00  G-2B002
# 23 2022-09-01      08:00    09:00  G-2B002
# 24 2022-09-01      09:00    10:00  G-2B002
# 25 2022-09-01      10:00    11:00  G-2B002
# 26 2022-09-01      11:00    12:00  G-2B002
# 27 2022-09-01      12:00    13:00  G-2B002
# 28 2022-09-01      13:00    14:00  G-2B002
# 29 2022-09-01      14:00    15:00  G-2B002
# 30 2022-09-01      15:00    16:00  G-2B002
# 31 2022-09-01      16:00    17:00  G-2B002
# 32 2022-09-01      17:00    18:00  G-2B002
# 33 2022-09-01      07:00    08:00  G-2B012
# 34 2022-09-01      08:00    09:00  G-2B012
# 35 2022-09-01      09:00    10:00  G-2B012
# 36 2022-09-01      10:00    11:00  G-2B012
# 37 2022-09-01      11:00    12:00  G-2B012
# 38 2022-09-01      12:00    13:00  G-2B012
# 39 2022-09-01      13:00    14:00  G-2B012
# 40 2022-09-01      14:00    15:00  G-2B012
# 41 2022-09-01      15:00    16:00  G-2B012
# 42 2022-09-01      16:00    17:00  G-2B012
# 43 2022-09-01      17:00    18:00  G-2B012
# 44 2022-09-01      07:00    08:00  G-2B013
# 45 2022-09-01      08:00    09:00  G-2B013
# 46 2022-09-01      09:00    10:00  G-2B013
# 47 2022-09-01      10:00    11:00  G-2B013
# 48 2022-09-01      11:00    12:00  G-2B013
# 49 2022-09-01      12:00    13:00  G-2B013

# %% [markdown]
# **ADD DURATION, DELETE END-DATE, ROUNDED HOUR, RENAME COLUMN**

# %%
import pandas as pd

# Delete the "END-TIME" column
new_df = new_df.drop("END-TIME", axis=1)

# Rename the "START-TIME" column to "Hour"
new_df = new_df.rename(columns={"START-TIME": "Hour", "DATE":"Date", "LOCATION" : "Location"})

# Add a new column "Duration" with all values set to 1
new_df["Duration"] = 1

# Rounded hour
# extract only the hour part from the Hour column, add ":00" to it, and convert it to datetime object
new_df['Hour'] = pd.to_datetime(new_df['Hour'].apply(lambda x: x.split(':')[0] + ':00'), format='%H:%M')
# extract the hour and minute parts from the datetime object and convert them back to string
new_df['Hour'] = new_df['Hour'].apply(lambda x: str(x.hour).zfill(2) + ':' + str(x.minute).zfill(2))


new_df.head(20)
# Out:
#          Date   Hour Location  Duration
# 0  2022-09-01  07:00  G-2A004         1
# 1  2022-09-01  08:00  G-2A004         1
# 2  2022-09-01  09:00  G-2A004         1
# 3  2022-09-01  10:00  G-2A004         1
# 4  2022-09-01  11:00  G-2A004         1
# 5  2022-09-01  12:00  G-2A004         1
# 6  2022-09-01  13:00  G-2A004         1
# 7  2022-09-01  14:00  G-2A004         1
# 8  2022-09-01  15:00  G-2A004         1
# 9  2022-09-01  16:00  G-2A004         1
# 10 2022-09-01  17:00  G-2A004         1
# 11 2022-09-01  07:00  G-2A005         1
# 12 2022-09-01  08:00  G-2A005         1
# 13 2022-09-01  09:00  G-2A005         1
# 14 2022-09-01  10:00  G-2A005         1
# 15 2022-09-01  11:00  G-2A005         1
# 16 2022-09-01  12:00  G-2A005         1
# 17 2022-09-01  13:00  G-2A005         1
# 18 2022-09-01  14:00  G-2A005         1
# 19 2022-09-01  15:00  G-2A005         1

# %% [markdown]
# **ROOM CAPACITY**

# %%
#ADDING ROOM CAPACITY
# Create a new column "Capacity" with default value as -1
new_df["Capacity"] = 0

# Define a dictionary to map Location values to Capacity values
capacity_map = {"G-0B007": 150,
                "G-1A002":	150,
                "G-1C002":	150,
                "G-0B015":	30,
                "G-4D011":	30,
                "G-4D013":	30,
                "G-1B001":	50,
                "G-1B002":	10,
                "G-1B003":	10,
                "G-1B004":	10,
                "G-1B005":	10,
                "G-3A005":	16,
                "G-3A007":	16,
                "G-3A007": 16,
                "G-3A010":	5,
                "G-3A010":	5,
                "G-3A012":	16,
                "G-3B007":	16,
                "G-3B012":	16,
                "G-3B013":	16,
                "G-3C011":	16,
                "G-3B008": 16,
                "G-3C007":	16,
                "G-3D001":	16,
                "G-0B009":	16,
                "G-3D002":	54,
                "G-3D005":	16,
                "G-3D006":	16,
                "G-4A013":	16,
                "G-4C005":	16,
                "G-4C006":	16,
                "G-4C008":	16,
                "G-4C013":	16,
                "G-5D003":	16,
                "G-5D005":	16,
                "G-5D006":	16,
                "G-2A003":	80,
                "G-2A006":	80,
                "G-2B009":	80,
                "G-2B010":	80,
                "G-2C006":	80,
                "G-0B018":	221,
                "G-0D004":	826,
                "G-0D006":	100,
                "G-1C003":	10,
                "G-1C004":	14,
                "G-1D003":	40,
                "G-1D006":	10,
                "G-2A004":	29,
                "G-2A005":	29,
                "G-2B002":	36,
                "G-2B012":	36,
                "G-2B013":	36,
                "G-2C001":	36,
                "G-2C002":	36,
                "G-2C003":	36,
                "G-2C004":	36,
                "G-2C007":	36,
                "G-2C008":	36,
                "G-4D003":	36,
                "G-4D006":	34,
                "G-4D008":	36,
                "G-1B012":	18,
                "G-2A007":	22,
                "G-2B001":	18,
                "G-2C005":	18,
                "G-3A014":	18,
                "G-3B001":	18,
                "G-3D003":	18,
                "G-4A020":	18,
                "G-4C012":	18,
                "G-1B008":	10,
                "G-1B009":	12,
                "G-1B016":	10,
                "G-4D001":	12,
                "G-4D005":	12,
                "G-4D007":	12,
                "G-4D009":	12,
                "G-4D010":	12,
                }

# Loop over rows in the dataframe and set Capacity based on Location
for i, row in new_df.iterrows():
    for location, capacity in capacity_map.items():
        if location in row["Location"]:
            new_df.at[i, "Capacity"] = capacity
new_df.head(20)
# Out:
#          Date   Hour Location  Duration  Capacity
# 0  2022-09-01  07:00  G-2A004         1        29
# 1  2022-09-01  08:00  G-2A004         1        29
# 2  2022-09-01  09:00  G-2A004         1        29
# 3  2022-09-01  10:00  G-2A004         1        29
# 4  2022-09-01  11:00  G-2A004         1        29
# 5  2022-09-01  12:00  G-2A004         1        29
# 6  2022-09-01  13:00  G-2A004         1        29
# 7  2022-09-01  14:00  G-2A004         1        29
# 8  2022-09-01  15:00  G-2A004         1        29
# 9  2022-09-01  16:00  G-2A004         1        29
# 10 2022-09-01  17:00  G-2A004         1        29
# 11 2022-09-01  07:00  G-2A005         1        29
# 12 2022-09-01  08:00  G-2A005         1        29
# 13 2022-09-01  09:00  G-2A005         1        29
# 14 2022-09-01  10:00  G-2A005         1        29
# 15 2022-09-01  11:00  G-2A005         1        29
# 16 2022-09-01  12:00  G-2A005         1        29
# 17 2022-09-01  13:00  G-2A005         1        29
# 18 2022-09-01  14:00  G-2A005         1        29
# 19 2022-09-01  15:00  G-2A005         1        29

# %% [markdown]
# **GROUP THE SAME HOUR AND DATE, SUM THE DURATION AND ROOM CAPACITY**

# %%
import pandas as pd

# group by Date and Hour and aggregate the other columns
grouped_df = new_df.groupby(['Date', 'Hour']).agg({
    'Location': lambda x: ', '.join(x),
    'Duration': 'sum',
    'Capacity': 'sum'
}).reset_index()

# print the grouped DataFrame
grouped_df.head(20)
# Out:
#          Date   Hour                                           Location  \
# 0  2022-09-01  07:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 1  2022-09-01  08:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 2  2022-09-01  09:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 3  2022-09-01  10:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 4  2022-09-01  11:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 5  2022-09-01  12:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 6  2022-09-01  13:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 7  2022-09-01  14:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 8  2022-09-01  15:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 9  2022-09-01  16:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 10 2022-09-01  17:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 11 2022-09-02  07:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 12 2022-09-02  08:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 13 2022-09-02  09:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 14 2022-09-02  10:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 15 2022-09-02  11:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 16 2022-09-02  12:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 17 2022-09-02  13:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 18 2022-09-02  14:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
# 19 2022-09-02  15:00  G-2A004, G-2A005, G-2B002, G-2B012, G-2B013, G...
#
#     Duration  Capacity
# 0         16       442
# 1         19       664
# 2         21       778
# 3         22       788
# 4         21       638
# 5         18       556
# 6         21       694
# 7         22       618
# 8         20       538
# 9         19       532
# 10        16       442
# 11        16       442
# 12        19       638
# 13        21       888
# 14        18       578
# 15        18       578
# 16        17       542
# 17        22       634
# 18        21       534
# 19        19       484

# %% [markdown]
# **DOWNLOAD THE DATASET**

# %%
from google.colab import files

#Save the new dataframe as a CSV file
grouped_df.to_csv('class_schedule2022-2023.csv', index=False)

#Download the CSV file to your local machine
files.download('class_schedule2022-2023.csv')
